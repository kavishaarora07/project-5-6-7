# %%
#importing libraries

import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('glass_indentification')
df
# Out:
#       ID       RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  \
# 0      1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...  ...
# 209  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
#       Type of glass
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ..              ...
# ...

# %%
df.head()
# Out:
#    ID       RI     Na    Mg    Al     Si     K    Ca   Ba   Fe   Type of glass
# 0   1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0               1
# 1   2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0               1
# 2   3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0               1
# 3   4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0               1
# 4   5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0               1

# %%
df.tail()
# Out:
#       ID       RI     Na   Mg    Al     Si     K    Ca    Ba   Fe  \
# 209  210  1.51623  14.14  0.0  2.88  72.61  0.08  9.18  1.06  0.0
# 210  211  1.51685  14.92  0.0  1.99  73.06  0.00  8.40  1.59  0.0
# 211  212  1.52065  14.36  0.0  2.02  73.42  0.00  8.44  1.64  0.0
# 212  213  1.51651  14.38  0.0  1.94  73.61  0.00  8.48  1.57  0.0
# 213  214  1.51711  14.23  0.0  2.08  73.36  0.00  8.62  1.67  0.0
#
#       Type of glass
# 209               7
# 210               7
# 211               7
# 212               7
# 213               7

# %%
#dropping id as it does not give relevant data
df=df.drop(['ID'],axis=1)
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe   Type of glass
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0               1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0               1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0               1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0               1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0               1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...             ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0               7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0               7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0               7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0               7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0               7
#
# [214 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# RI                0
# Na                0
#  Mg               0
#  Al               0
#  Si               0
#  K                0
#  Ca               0
#  Ba               0
#  Fe               0
#  Type of glass    0
# dtype: int64

# %% [markdown]
# # EDA

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [raw]
# univariate analysis

# %%
sns.distplot(df['RI'])
# Out:
# <AxesSubplot:xlabel='RI', ylabel='Density'>

# %%
sns.distplot(df['Na'])
# Out:
# <AxesSubplot:xlabel='Na', ylabel='Density'>

# %%
sns.distplot(df[' Mg'])
# Out:
# <AxesSubplot:xlabel=' Mg', ylabel='Density'>

# %%
sns.distplot(df[' Al'])
# Out:
# <AxesSubplot:xlabel=' Al', ylabel='Density'>

# %%
sns.distplot(df[' Si'])
# Out:
# <AxesSubplot:xlabel=' Si', ylabel='Density'>

# %%
sns.distplot(df[' K'])
# Out:
# <AxesSubplot:xlabel=' K', ylabel='Density'>

# %% [markdown]
# # bivariate analysis

# %%
sns.regplot(x='RI',y=' Type of glass',data=df)
# Out:
# <AxesSubplot:xlabel='RI', ylabel=' Type of glass'>

# %%
sns.scatterplot(x='Na',y=' Type of glass',data=df)
# Out:
# <AxesSubplot:xlabel='Na', ylabel=' Type of glass'>

# %%
sns.regplot(x=' Mg',y=' Type of glass',data=df)
# Out:
# <AxesSubplot:xlabel=' Mg', ylabel=' Type of glass'>

# %%
sns.regplot(x= ' Al',y=' Type of glass',data=df)
# Out:
# <AxesSubplot:xlabel=' Al', ylabel=' Type of glass'>

# %%
sns.scatterplot(x=' Si',y=' Type of glass',data=df)
# Out:
# <AxesSubplot:xlabel=' Si', ylabel=' Type of glass'>

# %%
sns.pairplot(df)

# %%
df.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe   Type of glass
# count  214.000000  214.000000  214.000000      214.000000
# mean     8.956963    0.175047    0.057009        2.780374
# std      1.423153    0.497219    0.097439        2.103739
# ...

# %% [markdown]
# if mean>median , data is right skewed and if median is greater than mean, data is left skewed.
#
# 1. RI mean and median has less difference so data is normal distributed
# 2. Na mean and median also has leff difference
# 3. Mg mean<median, data is left skewed
# 4. Al mean>median, data is right skewed
# 5. Si less diff between mean and median
# 6. K median>mean , left skewed data
# 7. Ca mean >median, right skewed data
# 8. Ba mean>median, right skewed data
# 9. Fe mean>median,right skewed data
# 10. type of glass we dont remove skewness in categorical data of target variable

# %%
df.shape
# Out:
# (214, 10)

# %% [markdown]
# # correlation checking¶

# %%
df.corr()
# Out:
#                       RI        Na        Mg        Al        Si         K  \
# RI              1.000000 -0.191885 -0.122274 -0.407326 -0.542052 -0.289833
# Na             -0.191885  1.000000 -0.273732  0.156794 -0.069809 -0.266087
#  Mg            -0.122274 -0.273732  1.000000 -0.481799 -0.165927  0.005396
#  Al            -0.407326  0.156794 -0.481799  1.000000 -0.005524  0.325958
#  Si            -0.542052 -0.069809 -0.165927 -0.005524  1.000000 -0.193331
#  K             -0.289833 -0.266087  0.005396  0.325958 -0.193331  1.000000
#  Ca             0.810403 -0.275442 -0.443750 -0.259592 -0.208732 -0.317836
#  Ba            -0.000386  0.326603 -0.492262  0.479404 -0.102151 -0.042618
#  Fe             0.143010 -0.241346  0.083060 -0.074402 -0.094201 -0.007719
#  Type of glass -0.164237  0.502898 -0.744993  0.598829  0.151565 -0.010054
#
#                       Ca        Ba        Fe   Type of glass
# RI              0.810403 -0.000386  0.143010       -0.164237
# ...

# %% [raw]
# correlation means relationship between variables i.e features. one independant and other dependant
#
# 1 - high correlation
# 0 - no correlation

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True,linewidth=0.5,linecolor='black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [raw]
# observation:
#
# type of glass and Ca has no correlation
# Ai and type of glass has highest correlation , followed by Ba
# mg has high negative correlation

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   RI              214 non-null    float64
#  1   Na              214 non-null    float64
#  2    Mg             214 non-null    float64
#  3    Al             214 non-null    float64
#  4    Si             214 non-null    float64
#  5    K              214 non-null    float64
#  6    Ca             214 non-null    float64
#  7    Ba             214 non-null    float64
#  8    Fe             214 non-null    float64
#  9    Type of glass  214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %% [markdown]
# OUTLIARS REMOVAL

# %%
df['RI'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df[' Mg'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Na'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df[' Al'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df[' Si'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df[' Ca'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df[' Ba'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df[' Fe'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # SKEWNESS

# %%
df.skew()
# Out:
# RI                1.625431
# Na                0.454181
#  Mg              -1.152559
#  Al               0.907290
#  Si              -0.730447
#  K                6.551648
#  Ca               2.047054
#  Ba               3.416425
#  Fe               1.754327
#  Type of glass    1.114915
# dtype: float64

# %% [markdown]
# we dont remove skewness in target variable

# %% [raw]
# +/- 0.5 is acceptable range

# %% [markdown]
# Data Cleaning

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
x=df.iloc[:0:-1]
x
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba    Fe   Type of glass
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.00               7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.00               7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.00               7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.00               7
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.00               7
# ..       ...    ...   ...   ...    ...   ...   ...   ...   ...             ...
# 5    1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00  0.26               1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.00               1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.00               1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.00               1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.00               1
#
# [213 rows x 10 columns]

# %%
def vif_cal():
    vif=pd.DataFrame()
    vif['VIF FACTOR']=[variance_inflation_factor(x.values,i)for i in range(x.shape[1])]
    vif['features']=x.columns
    print(vif)

# %%
vif_cal()
# Out:
#       VIF FACTOR        features
# 0  724115.181061              RI
# 1   13917.556972              Na
# 2     793.889012              Mg
# 3     176.931613              Al
# 4  366212.454333              Si
# 5      57.021140               K
# 6    8015.769607              Ca
# 7      27.498723              Ba
# 8       1.614112              Fe
# 9      10.736466   Type of glass

# %% [markdown]
# now we need to find out which input is giving low contribution to y.

# %%
df=df.drop(["RI"," Mg"],axis=1)
df
# Out:
#         Na    Al     Si     K    Ca    Ba   Fe   Type of glass
# 0    13.64  1.10  71.78  0.06  8.75  0.00  0.0               1
# 1    13.89  1.36  72.73  0.48  7.83  0.00  0.0               1
# 2    13.53  1.54  72.99  0.39  7.78  0.00  0.0               1
# 3    13.21  1.29  72.61  0.57  8.22  0.00  0.0               1
# 4    13.27  1.24  73.08  0.55  8.07  0.00  0.0               1
# ..     ...   ...    ...   ...   ...   ...  ...             ...
# 209  14.14  2.88  72.61  0.08  9.18  1.06  0.0               7
# 210  14.92  1.99  73.06  0.00  8.40  1.59  0.0               7
# 211  14.36  2.02  73.42  0.00  8.44  1.64  0.0               7
# 212  14.38  1.94  73.61  0.00  8.48  1.57  0.0               7
# 213  14.23  2.08  73.36  0.00  8.62  1.67  0.0               7
#
# [214 rows x 8 columns]

# %%
df.shape
# Out:
# (214, 8)

# %% [markdown]
# # removing outliars

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from scipy.stats import zscore
import numpy as np

# %%
z= np.abs(zscore(x))
z.shape
# Out:
# (214, 7)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([105, 106, 106, 106, 106, 107, 107, 110, 111, 112, 131, 145, 162,
#        163, 163, 163, 171, 171, 172, 172, 174, 184, 184, 188, 189, 201,
#        201, 203, 207, 213], dtype=int64), array([4, 0, 2, 4, 5, 2, 4, 4, 4, 4, 4, 6, 6, 1, 2, 5, 1, 3, 1, 3, 6, 0,
#        2, 2, 5, 2, 3, 5, 5, 5], dtype=int64))

# %%
x=x[(z<3).all(axis=1)]
x
# Out:
#         Na    Al     Si     K    Ca    Ba   Fe
# 0    13.64  1.10  71.78  0.06  8.75  0.00  0.0
# 1    13.89  1.36  72.73  0.48  7.83  0.00  0.0
# 2    13.53  1.54  72.99  0.39  7.78  0.00  0.0
# 3    13.21  1.29  72.61  0.57  8.22  0.00  0.0
# 4    13.27  1.24  73.08  0.55  8.07  0.00  0.0
# ..     ...   ...    ...   ...   ...   ...  ...
# 208  14.37  2.74  72.85  0.00  9.45  0.54  0.0
# 209  14.14  2.88  72.61  0.08  9.18  1.06  0.0
# 210  14.92  1.99  73.06  0.00  8.40  1.59  0.0
# 211  14.36  2.02  73.42  0.00  8.44  1.64  0.0
# 212  14.38  1.94  73.61  0.00  8.48  1.57  0.0
#
# [194 rows x 7 columns]

# %%
y= y[(z<3).all(axis=1)]
y.shape
# Out:
# (194,)

# %%
data_loss = (214-194)/214*100
data_loss
# Out:
# 9.345794392523365

# %% [markdown]
# # tranforming data to remove skewness

# %%
import sklearn
import scipy
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[ 3.75144846e-01, -7.05895157e-01, -1.55185559e+00, ...,
#          1.11819938e-03, -4.29499500e-01, -6.77737203e-01],
#        [ 7.32539190e-01, -7.32561974e-02, -3.70583600e-02, ...,
#         -1.05715663e+00, -4.29499500e-01, -6.77737203e-01],
#        [ 2.14037622e-01,  3.33352610e-01,  4.25596007e-01, ...,
#         -1.11977966e+00, -4.29499500e-01, -6.77737203e-01],
#        ...,
#        [ 2.08782892e+00,  1.25895709e+00,  5.53948190e-01, ...,
#         -3.81688285e-01,  2.49873753e+00, -6.77737203e-01],
#        [ 1.37327598e+00,  1.31667245e+00,  1.24045743e+00, ...,
#         -3.36777926e-01,  2.49875343e+00, -6.77737203e-01],
#        [ 1.39968197e+00,  1.16174672e+00,  1.62124252e+00, ...,
#         -2.92174639e-01,  2.49873007e+00, -6.77737203e-01]])

# %% [markdown]
# skewness is removed

# %% [markdown]
# # scaling part

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 3.75144846e-01, -7.05895157e-01, -1.55185559e+00, ...,
#          1.11819938e-03, -4.29499500e-01, -6.77737203e-01],
#        [ 7.32539190e-01, -7.32561974e-02, -3.70583600e-02, ...,
#         -1.05715663e+00, -4.29499500e-01, -6.77737203e-01],
#        [ 2.14037622e-01,  3.33352610e-01,  4.25596007e-01, ...,
#         -1.11977966e+00, -4.29499500e-01, -6.77737203e-01],
#        ...,
#        [ 2.08782892e+00,  1.25895709e+00,  5.53948190e-01, ...,
#         -3.81688285e-01,  2.49873753e+00, -6.77737203e-01],
#        [ 1.37327598e+00,  1.31667245e+00,  1.24045743e+00, ...,
#         -3.36777926e-01,  2.49875343e+00, -6.77737203e-01],
#        [ 1.39968197e+00,  1.16174672e+00,  1.62124252e+00, ...,
#         -2.92174639e-01,  2.49873007e+00, -6.77737203e-01]])

# %%
#oversampling the data

# %%
from imblearn.over_sampling import SMOTE
SM=SMOTE()
x,y= SM.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 1    70
# 2    70
# 3    70
# 5    70
# 6    70
# 7    70
# Name:  Type of glass, dtype: int64

# %% [raw]
# now the data is balanced through smote technique
#
# since the outcome has more than 2 variables its a multi class classification model

# %%
from sklearn.naive_bayes import GaussianNB

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report

# %%
Gs = GaussianNB()

# %% [raw]
# NOW SPLIITING THE DATASET

# %%
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    Gs.fit(x_train,y_train)
    pred_train=Gs.predict(x_train)
    pred_test=Gs.predict(x_test)
    if round(accuracy_score(y_train,pred_train)*100,1)==round(accuracy_score(y_test,pred_test)*100,1):
        print("at random state",i,"model performs v well")
        print("at random state:-",i)
        print("training accuracy is:-",accuracy_score(y_train,pred_train)*100)
        print("testing accuracy  is",accuracy_score(y_test,pred_test)*100)
# Out:
# at random state 30 model performs v well
# at random state:- 30
# training accuracy is:- 76.19047619047619
# testing accuracy  is 76.19047619047619
# at random state 116 model performs v well
# at random state:- 116
# training accuracy is:- 76.19047619047619
# testing accuracy  is 76.19047619047619
# at random state 128 model performs v well
# at random state:- 128
# training accuracy is:- 76.19047619047619
# testing accuracy  is 76.19047619047619
# at random state 131 model performs v well
# at random state:- 131
# training accuracy is:- 76.19047619047619
# testing accuracy  is 76.19047619047619
# at random state 210 model performs v well
# at random state:- 210
# training accuracy is:- 73.80952380952381
# testing accuracy  is 73.80952380952381
# at random state 376 model performs v well
# at random state:- 376
# training accuracy is:- 66.66666666666666
# testing accuracy  is 66.66666666666666
# at random state 386 model performs v well
# at random state:- 386
# ...

# %%
 x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=246,test_size=0.20)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        12
#            2       0.07      0.07      0.07        14
#            3       0.04      0.11      0.06         9
#            5       0.31      0.28      0.29        18
#            6       0.36      0.24      0.29        17
#            7       0.23      0.21      0.22        14
#
#     accuracy                           0.17        84
#    macro avg       0.17      0.15      0.16        84
# weighted avg       0.19      0.17      0.18        84

# %% [markdown]
# cross_validation_Score for gaussianNB

# %%
pred_gs = Gs.predict(x_test)
from sklearn.model_selection import cross_val_score
gss=accuracy_score(y_test,pred_gs)
for j in range(2,10):
    gsscore=cross_val_score(Gs,x,y,cv=j)
    gsc=gsscore.mean()
    print(" at cv:-",j)
    print("cross val score is-:",gsc*100)
    print("accuracy_Score is-:",gss*100)
    print("\n")
# Out:
#  at cv:- 2
# cross val score is-: 70.47619047619047
# accuracy_Score is-: 77.38095238095238
#
#
#  at cv:- 3
# cross val score is-: 72.3809523809524
# accuracy_Score is-: 77.38095238095238
#
#
#  at cv:- 4
# cross val score is-: 75.71428571428571
# accuracy_Score is-: 77.38095238095238
#
#
#  at cv:- 5
# cross val score is-: 74.76190476190476
# accuracy_Score is-: 77.38095238095238
#
#
#  at cv:- 6
# cross val score is-: 73.80952380952381
# accuracy_Score is-: 77.38095238095238
#
#
#  at cv:- 7
# cross val score is-: 74.76190476190474
# accuracy_Score is-: 77.38095238095238
#
#
#  at cv:- 8
# cross val score is-: 74.56005079825833
# accuracy_Score is-: 77.38095238095238
#
#
#  at cv:- 9
# cross val score is-: 74.78672011511975
# accuracy_Score is-: 77.38095238095238

# %% [markdown]
# IF CROSS VALIDATION AND ACCURACY HAS LESS DIFFERENCE,WE WILL TAKE THAT ONLY

# %%
gsscore_selected = cross_val_score(Gs,x,y,cv=4).mean()
print("the cv score is:",gsscore_selected,"\nthe accuracy score is",gss )
# Out:
# the cv score is: 0.7571428571428571
# the accuracy score is 0.7738095238095238

# %%
from sklearn.ensemble import GradientBoostingClassifier,BaggingClassifier,AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
RFC=RandomForestClassifier()
RFC.fit(x_train,y_train)
predRFC= RFC.predict(x_test)
print(accuracy_score(y_test,predRFC))
print(confusion_matrix(y_test,predRFC))
print(classification_report(y_test,predRFC))
# Out:
# 0.8928571428571429
# [[ 7  1  3  0  0  1]
#  [ 2 10  0  1  1  0]
#  [ 0  0  9  0  0  0]
#  [ 0  0  0 18  0  0]
#  [ 0  0  0  0 17  0]
#  [ 0  0  0  0  0 14]]
#               precision    recall  f1-score   support
#
#            1       0.78      0.58      0.67        12
#            2       0.91      0.71      0.80        14
#            3       0.75      1.00      0.86         9
#            5       0.95      1.00      0.97        18
#            6       0.94      1.00      0.97        17
#            7       0.93      1.00      0.97        14
#
#     accuracy                           0.89        84
#    macro avg       0.88      0.88      0.87        84
# weighted avg       0.89      0.89      0.89        84

# %%
score = cross_val_score(RFC,x,y,cv=4)
print(score)
print(score.mean())
print("diff between accuracy and cross val",accuracy_score(y_test,predRFC)-score.mean())
# Out:
# [0.84761905 0.85714286 0.83809524 0.84761905]
# 0.8476190476190476
# diff between accuracy and cross val 0.0452380952380953

# %%
from sklearn.svm import SVC
svc=SVC()
svc.fit(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.7857142857142857
# [[ 3  2  7  0  0  0]
#  [ 1  9  2  1  1  0]
#  [ 2  2  5  0  0  0]
#  [ 0  0  0 18  0  0]
#  [ 0  0  0  0 17  0]
#  [ 0  0  0  0  0 14]]
#               precision    recall  f1-score   support
#
#            1       0.50      0.25      0.33        12
#            2       0.69      0.64      0.67        14
#            3       0.36      0.56      0.43         9
#            5       0.95      1.00      0.97        18
#            6       0.94      1.00      0.97        17
#            7       1.00      1.00      1.00        14
#
#     accuracy                           0.79        84
#    macro avg       0.74      0.74      0.73        84
# weighted avg       0.79      0.79      0.78        84

# %%
score = cross_val_score(svc,x,y,cv=4)
print(score)
print(score.mean())
print("diff between accuracy and cross val",accuracy_score(y_test,predsvc)-score.mean())
# Out:
# [0.76190476 0.77142857 0.81904762 0.84761905]
# 0.7999999999999999
# diff between accuracy and cross val -0.014285714285714235

# %% [raw]
# here accuracy is less than cross value

# %%
gb=GradientBoostingClassifier()
gb.fit(x_train,y_train)
predgb=gb.predict(x_test)
print(accuracy_score(y_test,predgb))
print(confusion_matrix(y_test,predgb))
print(classification_report,predgb)
# Out:
# 0.8809523809523809
# [[ 7  2  3  0  0  0]
#  [ 4  9  0  0  1  0]
#  [ 0  0  9  0  0  0]
#  [ 0  0  0 18  0  0]
#  [ 0  0  0  0 17  0]
#  [ 0  0  0  0  0 14]]
# <function classification_report at 0x0000022295492790> [7 6 7 3 1 2 7 6 6 5 1 6 5 7 2 7 3 6 5 6 6 3 5 5 5 5 5 6 6 2 3 7 7 3 3 6 6
#  3 7 6 6 7 5 2 5 7 5 6 6 1 7 1 7 1 3 2 7 1 6 1 5 1 3 1 2 2 7 5 3 1 2 5 5 2
#  5 1 3 5 6 6 2 2 5 3]

# %%
core = cross_val_score(gb,x,y,cv=4)
print(score)
print(score.mean())
print("diff between accuracy and cross val",accuracy_score(y_test,predgb)-score.mean())
# Out:
# [0.76190476 0.77142857 0.81904762 0.84761905]
# 0.7999999999999999
# diff between accuracy and cross val 0.080952380952381

# %%
et=ExtraTreesClassifier()
et.fit(x_train,y_train)
predet =et.predict(x_test)
print(accuracy_score(y_test,predet))
print(confusion_matrix(y_test,predet))
print(classification_report(y_test,predet))
# Out:
# 0.8928571428571429
# [[ 5  1  5  0  0  1]
#  [ 0 12  0  1  1  0]
#  [ 0  0  9  0  0  0]
#  [ 0  0  0 18  0  0]
#  [ 0  0  0  0 17  0]
#  [ 0  0  0  0  0 14]]
#               precision    recall  f1-score   support
#
#            1       1.00      0.42      0.59        12
#            2       0.92      0.86      0.89        14
#            3       0.64      1.00      0.78         9
#            5       0.95      1.00      0.97        18
#            6       0.94      1.00      0.97        17
#            7       0.93      1.00      0.97        14
#
#     accuracy                           0.89        84
#    macro avg       0.90      0.88      0.86        84
# weighted avg       0.92      0.89      0.88        84

# %%
core = cross_val_score(et,x,y,cv=4)
print(score)
print(score.mean())
print("diff between accuracy and cross val",accuracy_score(y_test,predet)-score.mean())
# Out:
# [0.76190476 0.77142857 0.81904762 0.84761905]
# 0.7999999999999999
# diff between accuracy and cross val 0.09285714285714297

# %% [markdown]
# # till now svc was best

# %% [markdown]
# hyper paramter tuning

# %%
from sklearn.model_selection import GridSearchCV
parameters = {'kernel':['linear','rbf'],'C':[1,10]}
/

# %%
from sklearn import svm

# %%
svc=svm.SVC()

# %%
clf=GridSearchCV(svc,parameters)
clf.fit(x,y)
print(clf.best_score_)
print(clf.best_estimator_)
print(clf.best_params_)
# Out:
# 0.8404761904761905
# SVC(C=10)
# {'C': 10, 'kernel': 'rbf'}

# %%
sv=SVC(kernel='rbf',C=10)
sv.fit(x,y)

t=sv.score(x,y)
print(round(t,2))
# Out:
# 0.92

# %% [markdown]
# # model saving

# %%
import pickle

# %%
filename='glass_indentification.pkl'
pickle.dump(sv,open(filename,'wb'))

# %% [raw]
# conclusion

# %%
import numpy as np
a=np.array(y_test)
predicted = np.array(Gs.predict(x_test))
df_glass = pd.DataFrame({'Original':a,'predicted':predicted},index=range(len(a)))
df_glass
# Out:
#     Original  predicted
# 0          7          7
# 1          6          6
# 2          7          7
# 3          3          1
# 4          1          3
# ..       ...        ...
# 79         6          6
# 80         2          2
# 81         2          3
# 82         5          5
# 83         3          3
#
# [84 rows x 2 columns]

# %% [markdown]
# we can visualise there is some error in the outcome using the above model!!
